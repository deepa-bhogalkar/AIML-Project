# %% [markdown]
# ## imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler

# %% [markdown]
# ## Classification Models & Metrics

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    roc_auc_score
)

# %% [markdown]
# ## Data Pre-processing

# %%
print("Data Preprocessing")
df = pd.read_csv('swarm.csv')
# Out:
# Data Preprocessing

# %% [markdown]
# ## Missing Value treatment

# %%
df = df.dropna()

# %% [markdown]
# ## Handle Missing Values

# %%
xtrain_r = xtrain_r.fillna(xtrain_r.median(numeric_only=True))
xtest_r = xtest_r.fillna(xtest_r.median(numeric_only=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 xtrain_r = xtrain_r.fillna(xtrain_r.median(numeric_only=True))
#       2 xtest_r = xtest_r.fillna(xtest_r.median(numeric_only=True))
#
# NameError: name 'xtrain_r' is not defined

# %% [markdown]
# ## Label Encoding for Target

# %%
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col].astype(str))

# %% [markdown]
# ## Feature Selection

# %%
cols_to_drop = ['OBJECTID', 'REPORTID', 'STARTDATE', 'FINISHDATE', 'TmSTARTDAT', 'TmFINISHDA', 'LOCNAME', 'ACOMMENT', 'LOCUSTID', 'CAT', 'AREAHA']
X_all = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

# %% [markdown]
# ## Regression Analysis

# %%
X_all = df.drop(columns=['CAT', 'AREAHA'])
y_reg = df['AREAHA']

# %%
scaler_reg = MinMaxScaler()
X_reg_scaled = scaler_reg.fit_transform(X_all)

# %%
xtrain_r, xtest_r, ytrain_r, ytest_r = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 xtrain_r, xtest_r, ytrain_r, ytest_r = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)
#
# NameError: name 'X_reg' is not defined

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()

lin_reg.fit(xtrain_r, ytrain_r)

y_pred_r = lin_reg.predict(xtest_r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 from sklearn.linear_model import LinearRegression
#       2
#       3 lin_reg = LinearRegression()
#       4
# ----> 5 lin_reg.fit(xtrain_r, ytrain_r)
#       6
#       7 y_pred_r = lin_reg.predict(xtest_r)
#
# NameError: name 'xtrain_r' is not defined
