# %%
import h2o
from h2o.automl import H2OAutoML

h2o.init()

data = h2o.import_file("diabetes.csv")

print(data.head())
x = data.columns[:-1]
y = "Outcome"

data[y] = data[y].asfactor()

train, test = data.split_frame(ratios=[0.8], seed=42)

aml = H2OAutoML(
    max_models=10,
    seed=42,
    max_runtime_secs=300
)

aml.train(x=x, y=y, training_frame=train)


print("\nLeaderboard:")
print(aml.leaderboard)

best_model = aml.leader

predictions = best_model.predict(test)

print("\nPredictions:")
print(predictions.head())
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         24 mins 27 secs
# H2O_cluster_timezone:       Asia/Kolkata
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.10
# H2O_cluster_version_age:    2 months and 2 days
# H2O_cluster_name:           H2O_from_python_ASUS_jq71p0
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.811 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.13.9 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#   Pregnancies    Glucose    BloodPressure    SkinThickness    Insulin    BMI    DiabetesPedigreeFunction    Age    Outcome
#             6        148               72               35          0   33.6                       0.627     50          1
#             1         85               66               29          0   26.6                       0.351     31          0
#             8        183               64                0          0   23.3                       0.672     32          1
#             1         89               66               23         94   28.1                       0.167     21          0
#             0        137               40               35        168   43.1                       2.288     33          1
#             5        116               74                0          0   25.6                       0.201     30          0
#             3         78               50               32         88   31                         0.248     26          1
#            10        115                0                0          0   35.3                       0.134     29          0
#             2        197               70               45        543   30.5                       0.158     53          1
#             8        125               96                0          0    0                         0.232     54          1
# [10 rows x 9 columns]
#
# AutoML progress: |█
# 10:37:52.292: AutoML: XGBoost is not available; skipping it.
#
# ██████████████████████████████████████████████████████████████| (done) 100%
#
# Leaderboard:
# model_id                                                      auc    logloss     aucpr    mean_per_class_error      rmse       mse
# StackedEnsemble_BestOfFamily_1_AutoML_2_20260514_103752  0.842769   0.458152  0.737574                0.219804  0.386952  0.149732
# StackedEnsemble_AllModels_1_AutoML_2_20260514_103752     0.839366   0.465003  0.739513                0.224157  0.388118  0.150636
# GLM_1_AutoML_2_20260514_103752                           0.836      0.473992  0.712184                0.235952  0.391275  0.153096
# DeepLearning_1_AutoML_2_20260514_103752                  0.835188   0.493197  0.726775                0.22931   0.402626  0.162108
# GBM_5_AutoML_2_20260514_103752                           0.833432   0.472169  0.738827                0.238114  0.393892  0.155151
# GBM_2_AutoML_2_20260514_103752                           0.826433   0.481139  0.709428                0.245568  0.397811  0.158253
# GBM_1_AutoML_2_20260514_103752                           0.826402   0.483407  0.692873                0.235032  0.397919  0.15834
# GBM_3_AutoML_2_20260514_103752                           0.82326    0.483208  0.707215                0.24007   0.398793  0.159036
# DRF_1_AutoML_2_20260514_103752                           0.822715   0.583868  0.703541                0.247172  0.399119  0.159296
# GBM_4_AutoML_2_20260514_103752                           0.821843   0.484709  0.716383                0.244302  0.398767  0.159015
# [12 rows x 7 columns]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#
# Predictions:
#   predict        p0         p1
#         0  0.780607  0.219393
#         1  0.293636  0.706364
#         1  0.124621  0.875379
#         0  0.631418  0.368582
#         1  0.292486  0.707514
#         0  0.967526  0.0324739
#         1  0.16877   0.83123
#         1  0.439337  0.560663
#         0  0.966895  0.0331046
#         1  0.254976  0.745024
# [10 rows x 3 columns]
